# %% [markdown]
# On Local

# %%
from azureml.core import Environment, Workspace, environment

# %%
# ws = Workspace(workspace_name='viper_pipelines', subscription_id='c4f1c7f3-9206-409f-a333-5b89a516e5dd', resource_group='vdeep-ct-prod')
# ws.get_details()
ws = Workspace.from_config()
# Out:
# ...
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.

# %%
Environment.list(ws).keys()
# Out:
# dict_keys(['deep_transfer_env_clip', 'teacher_model_feature_extraction_env', 'deep_transfer_env_data_prep_v6', 'deep_transfer_env_data_prep_v6_try', 'potholes_env', 'seer_test', 'flask_test', 'seer_test_new', 'seer_inference', 'seer_inference_new', 'seer_inference_old', 'seer_inference_exp', 'seer_inference_exp1', 'seer_inference_exp2', 'seer_inference_exp3', 'seer_inference_exp4', 'seer_inference_req', 'deep_transfer_env_seer', 'seer_inference_req2', 'seer_inference_req3', 'seer_inference_req4', 'sup_con', 'moco_train', 'moco_train2', 'moco_train3', 'seer_hf', 'seer_hf2', 'seer_hf3', 'seer_hf_light', 'vehicle_batch_training', 'vehicle_batch_training_v2', 'moco_train_terminal', 'deep_transfer_env', 'deep_transfer_mtl_env', 'deep_transfer_mtl_env_azureml', 'logger-tf', 'deep_transfer_rapdis_env_azureml', 'deep_transfer_rapdis_tf_env', 'deep_transfer_rapdis_tf_env_with_pip', 'deep_transfer_glip_docker', 'deep_transfer_glip', 'deep_transfer_glip_git', 'deep_transfer_glip_scratch', 'deep
# ...

# %%
env = Environment.from_dockerfile(name="muttiv4", dockerfile="../deployment/docker-mutti/Dockerfile")

# %%
env.build(workspace=ws, image_build_compute="gpupoolt4nc16as")
# Out:
# Building a non-registered environment is not supported. Registering environment.
